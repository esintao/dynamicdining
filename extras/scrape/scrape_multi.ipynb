# %%
import pandas as pd
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import random

# %%
# df = pd.read_csv('revised_recipes.csv')
# df['web_surfix'] = (df['name'].astype(str) + ' ' + df['id'].astype(str)).str.replace(' ', '-')
# #add columns to df for scraped data
# df['scraped_info'] = None
# df['amount_list'] = None
# df['unit_list'] = None
# df['full_text_list'] = None

# %%
df = pd.read_csv('scraped_recipe_ingredients.csv')
df.iloc[17]
# Out:
# name                              junior s white meat chicken salad
# id                                                           156275
# minutes                                                          30
# contributor_id                                                64780
# submitted                                                2006-02-16
# tags              ['30-minutes-or-less', 'time-to-make', 'course...
# nutrition                [317.5, 25.0, 10.0, 50.0, 65.0, 18.0, 2.0]
# n_steps                                                           9
# steps             ['to cook the chicken: fill a large saucepan h...
# description       whenever in nyc, i always try to cross the bri...
# ingredients       ['celery leaves', 'salt', 'white pepper', 'bon...
# n_ingredients                                                    11
# web_surfix                 junior-s-white-meat-chicken-salad-156275
# scraped_info                                                    NaN
# amount_list       ['', '1', '1⁄8', '2', '1', '1', '1', '3⁄4', '1...
# unit_list         ['celery', 'teaspoon', 'teaspoon', 'lbs', 'tab...
# full_text_list    ['celery leaves (optional)', 'teaspoon salt', ...
# Name: 17, dtype: object

# %%
def scrape_recipe(web_surfix):
    
    url = f'https://www.food.com/recipe/{web_surfix}/'
    # Code to scrape the recipe from the URL
    # This is a placeholder for the actual scraping logic

    # Initialize your driver (adjust for Chrome/Firefox as needed)
    driver = webdriver.Chrome()
    driver.get(url)
    time.sleep(random.uniform(2,3))  # Optional: wait a moment before starting the scraping

    amount_list = []
    unit_list = []
    full_text_list = []

    # 1. Locate the main ingredient list container
    try:
        ingredient_list = driver.find_element(By.CLASS_NAME, "ingredient-list")
        # Alternatively, use the full class if needed:
        # ingredient_list = driver.find_element(By.CSS_SELECTOR, ".ingredient-list.svelte-ik1ga1")
        
        # 2. Find all list items (li) inside the container
        ingredients = ingredient_list.find_elements(By.TAG_NAME, "li")

        for item in ingredients:
            try:
                # Extract the raw quantity string
                qty_el = item.find_element(By.CLASS_NAME, "ingredient-quantity")
                quantity = qty_el.text.strip()
                
                # Extract the text description string
                text_el = item.find_element(By.CLASS_NAME, "ingredient-text")
                full_text = text_el.text.strip()
                
                # 3. Regex logic to capture the unit
                # This looks inside parentheses if they exist, or grabs the first word
                unit_match = re.search(r'^\((.*?)\)|^(\w+)', full_text)
                
                unit = ""
                if unit_match:
                    # Group 1 handles parentheses like "(16 ounce) can" -> "16 ounce"
                    # Group 2 handles normal first words like "teaspoon salt" -> "teaspoon"
                    unit = unit_match.group(1) if unit_match.group(1) else unit_match.group(2)
                
                amount_list.append(quantity)
                unit_list.append(unit)
                full_text_list.append(full_text)
            except Exception as e:
                # Handles empty list items or structure variations gracefully
                continue

    finally:
        time.sleep(random.uniform(1,2))  # Optional: wait a moment before closing the driver
        driver.quit()
    
      # Ensure the driver has fully closed before proceeding

    return pd.Series({
        'amount_list': amount_list,
        'unit_list': unit_list,
        'full_text_list': full_text_list
    })

# %%
target_cols = ['amount_list', 'unit_list', 'full_text_list']
df[target_cols] = df['web_surfix'].apply(scrape_recipe)

# %%
# Returns all index labels where the column 'ingredient' is exactly 'egg'
matching_indices = df[df['name'] == 'cashew nut chicken'].index

print(matching_indices)
# Out:
# Index([999], dtype='int64')

# %%
df.iloc[999]
# Out:
# name                                             cashew nut chicken
# id                                                            81209
# minutes                                                          30
# contributor_id                                                27416
# submitted                                                2004-01-15
# tags              ['30-minutes-or-less', 'time-to-make', 'course...
# nutrition          [2611.6, 343.0, 59.0, 133.0, 120.0, 203.0, 39.0]
# n_steps                                                          13
# steps             ['cut chicken across grain into slivers , 1 / ...
# description       these are tender chicken breasts cooked with c...
# ingredients       ['boneless skinless chicken breast', 'black pe...
# n_ingredients                                                    16
# web_surfix                                 cashew-nut-chicken-81209
# scraped_info                                                    NaN
# amount_list       ['1', '1⁄8', '1⁄16', '1', '2', '1', '4', '1⁄4'...
# unit_list         ['large', 'teaspoon', 'teaspoon', 'teaspoon', ...
# full_text_list    ['large boneless skinless chicken breast', 'te...
# Name: 999, dtype: object

# %%
# Fix single row error by directly assigning the scraped data to the specific row
row_index = 999

df['amount_list'] = df['amount_list'].astype(object)
df['unit_list'] = df['unit_list'].astype(object)
df['full_text_list'] = df['full_text_list'].astype(object)

# 2. Now you can assign the scraper output to a single row in ONE clean line:
df.loc[row_index, ['amount_list', 'unit_list', 'full_text_list']] = scrape_recipe(df.at[row_index, 'web_surfix'])

df.iloc[row_index]
df.to_csv('scraped_recipe_ingredients.csv', index=False)

# %%
df.to_csv('scraped_recipe_ingredients.csv', index=False)
