# %%
import pandas as pd

# %%
user_df = pd.DataFrame({'u_id': [1,2,3], 'username': ['dualipa', 'konradfhp', 'esintao'], 'email': ['dualipa@example.com', 'bjv627@alumni.ku.dk', 'cxq772@alumni.ku.dk'], 'password': ['password123', 'berry','banana']})

household_df = pd.DataFrame({'h_id': [1,2,2], 'h_name': ['thelipahouse', 'dis2026'], 'h_password': ['password123', 'bananaberry']})

member_of_df = pd.DataFrame({'u_id': [1,2,3], 'h_id': [1,2,2]})

review_df = pd.DataFrame({'r_id': [], 'u_id': [], 'stars': [], 'comment': []})
